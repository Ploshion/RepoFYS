-- %% [markdown]
-- # [dbo].[Actores]

-- %%
USE [Movie]
GO

-- %%
/****** Object:  Table [dbo].[Actores]    Script Date: 29/06/2023 5:12:33 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Actores](
	[IdActor] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](150) NOT NULL,
	[Apellido] [varchar](150) NOT NULL,
	[Pais] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdActor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Directores]

-- %%
/****** Object:  Table [dbo].[Directores]    Script Date: 29/06/2023 5:12:33 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Directores](
	[IdDirector] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](150) NOT NULL,
	[Apellido] [varchar](150) NOT NULL,
	[IdPais] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdDirector] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Generos]

-- %%
/****** Object:  Table [dbo].[Generos]    Script Date: 29/06/2023 5:12:33 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Generos](
	[IdGenero] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](150) NOT NULL,
 CONSTRAINT [PK_Generos] PRIMARY KEY CLUSTERED 
(
	[IdGenero] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Paises]

-- %%
/****** Object:  Table [dbo].[Paises]    Script Date: 29/06/2023 5:12:33 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Paises](
	[IdPais] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](150) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdPais] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Peliculas]

-- %%
/****** Object:  Table [dbo].[Peliculas]    Script Date: 29/06/2023 5:12:33 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Peliculas](
	[IdPelicula] [int] IDENTITY(1,1) NOT NULL,
	[Genero] [int] NOT NULL,
	[Pais] [int] NOT NULL,
	[Actor] [int] NOT NULL,
	[Director] [int] NOT NULL,
	[titulo] [varchar](max) NOT NULL,
	[Reseña] [varchar](max) NOT NULL,
	[ImagenUrl] [varchar](max) NOT NULL,
	[CodigoTrailer] [varchar](max) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdPelicula] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 29/06/2023 5:12:33 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[IdUsuario] [int] IDENTITY(1,1) NOT NULL,
	[Usuario] [varchar](50) NOT NULL,
	[Clave] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Usuarios] PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Actores]

-- %%
SET IDENTITY_INSERT [dbo].[Actores] ON 
INSERT [dbo].[Actores] ([IdActor], [Nombre], [Apellido], [Pais]) VALUES (1, N'Leonardo', N'DiCaprio', 1)
INSERT [dbo].[Actores] ([IdActor], [Nombre], [Apellido], [Pais]) VALUES (2, N'Vin', N'Diesel', 2)
INSERT [dbo].[Actores] ([IdActor], [Nombre], [Apellido], [Pais]) VALUES (15, N'Carlos Enrique', N'Cortes Cardona', 4)
SET IDENTITY_INSERT [dbo].[Actores] OFF
GO

-- %% [markdown]
-- # [dbo].[Directores]

-- %%
SET IDENTITY_INSERT [dbo].[Directores] ON 
INSERT [dbo].[Directores] ([IdDirector], [Nombre], [Apellido], [IdPais]) VALUES (6, N'Martin ', N'Scorsese', 2)
SET IDENTITY_INSERT [dbo].[Directores] OFF
GO

-- %% [markdown]
-- # [dbo].[Generos]

-- %%
SET IDENTITY_INSERT [dbo].[Generos] ON 
INSERT [dbo].[Generos] ([IdGenero], [Nombre]) VALUES (1, N'Terror')
INSERT [dbo].[Generos] ([IdGenero], [Nombre]) VALUES (2, N'Accion')
INSERT [dbo].[Generos] ([IdGenero], [Nombre]) VALUES (3, N'Ficcion')
SET IDENTITY_INSERT [dbo].[Generos] OFF
GO

-- %% [markdown]
-- # [dbo].[Paises]

-- %%
SET IDENTITY_INSERT [dbo].[Paises] ON 
INSERT [dbo].[Paises] ([IdPais], [Nombre]) VALUES (1, N'Colombia')
INSERT [dbo].[Paises] ([IdPais], [Nombre]) VALUES (2, N'Ecuador')
INSERT [dbo].[Paises] ([IdPais], [Nombre]) VALUES (4, N'Peru')
INSERT [dbo].[Paises] ([IdPais], [Nombre]) VALUES (11, N'string')
INSERT [dbo].[Paises] ([IdPais], [Nombre]) VALUES (12, N'Dinamarca')
SET IDENTITY_INSERT [dbo].[Paises] OFF
GO

-- %% [markdown]
-- # [dbo].[Peliculas]

-- %%
SET IDENTITY_INSERT [dbo].[Peliculas] ON 
INSERT [dbo].[Peliculas] ([IdPelicula], [Genero], [Pais], [Actor], [Director], [titulo], [Reseña], [ImagenUrl], [CodigoTrailer]) VALUES (6, 1, 1, 1, 1, N'PELI PRUEBA', N'ES UNA PELI DE PRUEBA', N'https://image.tmdb.org/t/p/w780/fiVW06jE7z9YnO4trhaMEdclSiC.jpg', N'https://youtu.be/4TOpS3cdb3c')
INSERT [dbo].[Peliculas] ([IdPelicula], [Genero], [Pais], [Actor], [Director], [titulo], [Reseña], [ImagenUrl], [CodigoTrailer]) VALUES (19, 3, 12, 15, 6, N'LA PRUEBA DE AGREGAR', N'PROBANDO AGREGAR', N'https://image.tmdb.org/t/p/w780/fiVW06jE7z9YnO4trhaMEdclSiC.jpg', N'https://youtu.be/3j_SErnxepk')
SET IDENTITY_INSERT [dbo].[Peliculas] OFF
GO

-- %% [markdown]
-- # [FK_Actores_Paises]

-- %%
ALTER TABLE [dbo].[Actores]  WITH CHECK ADD  CONSTRAINT [FK_Actores_Paises] FOREIGN KEY([Pais])
REFERENCES [dbo].[Paises] ([IdPais])
GO
ALTER TABLE [dbo].[Actores] CHECK CONSTRAINT [FK_Actores_Paises]
GO

-- %% [markdown]
-- # [FK_Directores_Directores]

-- %%
ALTER TABLE [dbo].[Directores]  WITH CHECK ADD  CONSTRAINT [FK_Directores_Directores] FOREIGN KEY([IdDirector])
REFERENCES [dbo].[Directores] ([IdDirector])
GO
ALTER TABLE [dbo].[Directores] CHECK CONSTRAINT [FK_Directores_Directores]
GO

-- %% [markdown]
-- # [FK_Peliculas_Actores]

-- %%
ALTER TABLE [dbo].[Peliculas]  WITH CHECK ADD  CONSTRAINT [FK_Peliculas_Actores] FOREIGN KEY([Actor])
REFERENCES [dbo].[Actores] ([IdActor])
GO
ALTER TABLE [dbo].[Peliculas] CHECK CONSTRAINT [FK_Peliculas_Actores]
GO

-- %% [markdown]
-- # [FK_Peliculas_Generos]

-- %%
ALTER TABLE [dbo].[Peliculas]  WITH CHECK ADD  CONSTRAINT [FK_Peliculas_Generos] FOREIGN KEY([Genero])
REFERENCES [dbo].[Generos] ([IdGenero])
GO
ALTER TABLE [dbo].[Peliculas] CHECK CONSTRAINT [FK_Peliculas_Generos]
GO

-- %% [markdown]
-- # [FK_Peliculas_Paises]

-- %%
ALTER TABLE [dbo].[Peliculas]  WITH CHECK ADD  CONSTRAINT [FK_Peliculas_Paises] FOREIGN KEY([Pais])
REFERENCES [dbo].[Paises] ([IdPais])
GO
ALTER TABLE [dbo].[Peliculas] CHECK CONSTRAINT [FK_Peliculas_Paises]
GO
